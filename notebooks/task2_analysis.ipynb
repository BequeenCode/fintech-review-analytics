# %% [markdown]
# # Task 2: Sentiment and Thematic Analysis
#
# This notebook demonstrates partial progress for Task 2. It loads the Task 2 dataset produced by `scripts/run_task2.py` and inspects sentiment and theme distributions.
#
# - Sentiment scoring uses VADER as a lightweight baseline.
# - Theme extraction uses TF-IDF keyword patterns mapped to business-relevant categories.

# %%
from pathlib import Path
import pandas as pd

data_path = Path('data/task2_sentiment_thematic.csv')
if data_path.exists():
    df = pd.read_csv(data_path)
    display(df.head())
else:
    print('Run scripts/run_task2.py first to generate', data_path)
# Out:
# Run scripts/run_task2.py first to generate data\task2_sentiment_thematic.csv
